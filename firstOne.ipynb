# %% [markdown]
# You're here. Good! The purpose of this notebook is to simply run the following code cell. Press the Run cell button (that triangle-looking thing when you hover your mouse over the following cell).
#
# This program asks for a purchase amount and then takes 6% for a discount. For the purchase amount, enter 120 exactly. Do not put a $ in front of the number. What's output?

# %%
discountRate = 0.06

purchase = float(input("Enter the purchase amount: "))

discount = purchase * discountRate
cost = purchase - discount

print("The final cost is " + str(cost))
# Out:
# Enter the purchase amount: 120
# The final cost is 112.8
